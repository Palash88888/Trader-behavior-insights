# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set(style="whitegrid")

# %%
pd.read_csv("historical_data.csv")
# Out:
#                                            Account      Coin  Execution Price  \
# 0       0xae5eacaf9c6b9111fd53034a602c192a04e082ed      @107           7.9769
# 1       0xae5eacaf9c6b9111fd53034a602c192a04e082ed      @107           7.9800
# 2       0xae5eacaf9c6b9111fd53034a602c192a04e082ed      @107           7.9855
# 3       0xae5eacaf9c6b9111fd53034a602c192a04e082ed      @107           7.9874
# 4       0xae5eacaf9c6b9111fd53034a602c192a04e082ed      @107           7.9894
# ...                                            ...       ...              ...
# 211219  0x72743ae2822edd658c0c50608fd7c5c501b2afbd  FARTCOIN           1.1010
# 211220  0x72743ae2822edd658c0c50608fd7c5c501b2afbd  FARTCOIN           1.1010
# 211221  0x72743ae2822edd658c0c50608fd7c5c501b2afbd  FARTCOIN           1.1010
# 211222  0x72743ae2822edd658c0c50608fd7c5c501b2afbd  FARTCOIN           1.1010
# 211223  0x72743ae2822edd658c0c50608fd7c5c501b2afbd  FARTCOIN           1.1010
#
# ...

# %%
pd.read_csv("fear_greed_index.csv")
# Out:
#        timestamp  value classification        date
# 0     1517463000     30           Fear  2018-02-01
# 1     1517549400     15   Extreme Fear  2018-02-02
# 2     1517635800     40           Fear  2018-02-03
# 3     1517722200     24   Extreme Fear  2018-02-04
# 4     1517808600     11   Extreme Fear  2018-02-05
# ...          ...    ...            ...         ...
# 2639  1745818200     54        Neutral  2025-04-28
# 2640  1745904600     60          Greed  2025-04-29
# 2641  1745991000     56          Greed  2025-04-30
# 2642  1746077400     53        Neutral  2025-05-01
# 2643  1746163800     67          Greed  2025-05-02
#
# [2644 rows x 4 columns]

# %%
trader_df = pd.read_csv("historical_data.csv")
sentiment_df = pd.read_csv("fear_greed_index.csv")

# %%
print(trader_df.columns.tolist())
# Out:
# ['Account', 'Coin', 'Execution Price', 'Size Tokens', 'Size USD', 'Side', 'Timestamp IST', 'Start Position', 'Direction', 'Closed PnL', 'Transaction Hash', 'Order ID', 'Crossed', 'Fee', 'Trade ID', 'Timestamp']

# %%
print(sentiment_df.columns.tolist())
# Out:
# ['timestamp', 'value', 'classification', 'date']

# %%
trader_df.columns = trader_df.columns.str.strip()
sentiment_df.columns = sentiment_df.columns.str.strip()

# %%
trader_df['Timestamp IST'] = pd.to_datetime(trader_df['Timestamp IST'], errors='coerce')
sentiment_df['date'] = pd.to_datetime(sentiment_df['date'], errors='coerce')

# %%
trader_df['Date'] = trader_df['Timestamp IST'].dt.date
sentiment_df['Date'] = sentiment_df['date'].dt.date

# %%
merged_df = pd.merge(trader_df, sentiment_df, on='Date', how='left')

# %%
print(merged_df.head())
# Out:
#                                       Account  Coin  Execution Price  \
# 0  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9769
# 1  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9800
# 2  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9855
# 3  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9874
# 4  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9894
#
#    Size Tokens  Size USD Side       Timestamp IST  Start Position Direction  \
# 0       986.87   7872.16  BUY 2024-02-12 22:50:00        0.000000       Buy
# 1        16.00    127.68  BUY 2024-02-12 22:50:00      986.524596       Buy
# 2       144.09   1150.63  BUY 2024-02-12 22:50:00     1002.518996       Buy
# 3       142.98   1142.04  BUY 2024-02-12 22:50:00     1146.558564       Buy
# 4         8.73     69.75  BUY 2024-02-12 22:50:00     1289.488521       Buy
#
#    Closed PnL  ...     Order ID  Crossed       Fee      Trade ID  \
# ...

# %%
merged_df = merged_df.dropna(subset=['classification'])

# %%
sentiment_summary = merged_df.groupby('classification')['Closed PnL'].agg(['count', 'mean', 'sum']).reset_index()

# %%
sentiment_summary.columns = ['Sentiment', 'Trade Count', 'Average PnL', 'Total PnL']

# %%
print(sentiment_summary)
# Out:
#        Sentiment  Trade Count  Average PnL     Total PnL
# 0   Extreme Fear         5411    47.446302  2.567319e+05
# 1  Extreme Greed        34393    73.144030  2.515643e+06
# 2           Fear        47315    56.544720  2.675413e+06
# 3          Greed        48492    35.652184  1.728846e+06
# 4        Neutral        32246    31.746470  1.023697e+06

# %%
plt.figure(figsize=(8, 5))
sns.barplot(data=sentiment_summary, x='Sentiment', y='Average PnL', palette='coolwarm')
plt.title('Average Closed PnL by Market Sentiment')
plt.xlabel('Market Sentiment')
plt.ylabel('Average Closed PnL')
plt.grid(True, linestyle='--', alpha=0.3)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.barplot(data=sentiment_summary, x='Sentiment', y='Total PnL', palette='viridis')
plt.title('Total Closed PnL by Market Sentiment')
plt.xlabel('Market Sentiment')
plt.ylabel('Total Closed PnL')
plt.grid(True, linestyle='--', alpha=0.3)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.barplot(data=sentiment_summary, x='Sentiment', y='Trade Count', palette='pastel')
plt.title('Number of Trades by Market Sentiment')
plt.xlabel('Market Sentiment')
plt.ylabel('Number of Trades')
plt.grid(True, linestyle='--', alpha=0.3)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.lineplot(data=sentiment_summary, x='Sentiment', y='Average PnL', marker='o', color='orange')
plt.title('Trend of Average PnL by Sentiment')
plt.xlabel('Market Sentiment')
plt.ylabel('Average PnL')
plt.grid(True, linestyle='--', alpha=0.3)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6, 6))
plt.pie(sentiment_summary['Trade Count'], labels=sentiment_summary['Sentiment'],
        autopct='%1.1f%%', startangle=140, colors=sns.color_palette('pastel'))
plt.title('Trade Distribution by Sentiment')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=merged_df, x='classification', y='Closed PnL', palette='coolwarm')
plt.title('Closed PnL Distribution by Sentiment')
plt.xlabel('Market Sentiment')
plt.ylabel('Closed PnL')
plt.grid(True, linestyle='--', alpha=0.3)
plt.tight_layout()
plt.show()

# %%
merged_df['Closed PnL'] = pd.to_numeric(merged_df['Closed PnL'], errors='coerce')

# %%
sns.boxplot(data=merged_df, x='classification', y='Closed PnL', palette='coolwarm', showfliers=False)
# Out:
# <AxesSubplot:xlabel='classification', ylabel='Closed PnL'>

# %%
order = ['Extreme Fear', 'Fear', 'Neutral', 'Greed', 'Extreme Greed']
sns.barplot(data=sentiment_summary, x='Sentiment', y='Average PnL', palette='coolwarm', order=order)
# Out:
# <AxesSubplot:xlabel='Sentiment', ylabel='Average PnL'>

# %%
sentiment_map = {'Extreme Fear':0, 'Fear':1, 'Neutral':2, 'Greed':3, 'Extreme Greed':4}
merged_df['sentiment_score'] = merged_df['classification'].map(sentiment_map)

# %%
corr = merged_df[['sentiment_score', 'Closed PnL']].corr()
print(corr)
# Out:
#                  sentiment_score  Closed PnL
# sentiment_score          1.00000     0.00403
# Closed PnL               0.00403     1.00000
